# %%
import pandas as pd
from nba_api.stats.endpoints import playergamelog

# %%
## Search for Player ID

player = players.find_players_by_full_name("Anthony Edwards")[0]
print(player)
# Out:
# {'id': 1630162, 'full_name': 'Anthony Edwards', 'first_name': 'Anthony', 'last_name': 'Edwards', 'is_active': True}

# %%
#Micheal Porter Jr. Stats
gamelog = playergamelog.PlayerGameLog(player_id='1629008', season='2024-25',season_type_all_star='Playoffs')
df_mpj = gamelog.get_data_frames()[0]
df_mpj["Player_Name"] = 'Michael Porter Jr.'
df_mpj
# Out:
#    SEASON_ID  Player_ID     Game_ID     GAME_DATE      MATCHUP WL  MIN  FGM  \
# 0      42024    1629008  0042400227  May 18, 2025    DEN @ OKC  L   23    3
# 1      42024    1629008  0042400226  May 15, 2025  DEN vs. OKC  W   29    4
# 2      42024    1629008  0042400225  May 13, 2025    DEN @ OKC  L   29    1
# 3      42024    1629008  0042400224  May 11, 2025  DEN vs. OKC  L   34    1
# 4      42024    1629008  0042400223  May 09, 2025  DEN vs. OKC  W   42    7
# 5      42024    1629008  0042400222  May 07, 2025    DEN @ OKC  L   25    2
# 6      42024    1629008  0042400221  May 05, 2025    DEN @ OKC  W   24    1
# 7      42024    1629008  0042400177  May 03, 2025  DEN vs. LAC  W   30    6
# 8      42024    1629008  0042400176  May 01, 2025    DEN @ LAC  L   24    2
# 9      42024    1629008  0042400175  Apr 29, 2025  DEN vs. LAC  W   37    5
# 10     42024    1629008  0042400174  Apr 26, 2025    DEN @ LAC  W   42    6
# ...

# %%
#Jayson Tatum Stats
gamelog = playergamelog.PlayerGameLog(player_id='1628369', season='2024-25',season_type_all_star='Playoffs')
df_jt = gamelog.get_data_frames()[0]
df_jt["Player_Name"] = 'Jayson Tatum'
df_jt
# Out:
#   SEASON_ID  Player_ID     Game_ID     GAME_DATE      MATCHUP WL  MIN  FGM  \
# 0     42024    1628369  0042400214  May 12, 2025    BOS @ NYK  L   40   16
# 1     42024    1628369  0042400213  May 10, 2025    BOS @ NYK  W   40    8
# 2     42024    1628369  0042400212  May 07, 2025  BOS vs. NYK  L   42    5
# 3     42024    1628369  0042400211  May 05, 2025  BOS vs. NYK  L   44    7
# 4     42024    1628369  0042400115  Apr 29, 2025  BOS vs. ORL  W   34   10
# 5     42024    1628369  0042400114  Apr 27, 2025    BOS @ ORL  W   42   10
# 6     42024    1628369  0042400113  Apr 25, 2025    BOS @ ORL  L   39   10
# 7     42024    1628369  0042400111  Apr 20, 2025  BOS vs. ORL  W   40    8
#
#    FGA  FG_PCT  ...  REB  AST  STL  BLK  TOV  PF  PTS  PLUS_MINUS  \
# 0   28   0.571  ...    8    4    4    2    4   3   42          -9
# 1   20   0.400  ...    9    7    2    0    3   4   22          23
# 2   19   0.263  ...   14    5    3    1    3   2   13           3
# ...

# %%
#KAT Stats
gamelog = playergamelog.PlayerGameLog(player_id='1626157', season='2024-25',season_type_all_star='Playoffs')
df_kat = gamelog.get_data_frames()[0]
df_kat["Player_Name"] = 'Karl-Anthony Towns'
df_kat
# Out:
#    SEASON_ID  Player_ID     Game_ID     GAME_DATE      MATCHUP WL  MIN  FGM  \
# 0      42024    1626157  0042400306  May 31, 2025    NYK @ IND  L   38    8
# 1      42024    1626157  0042400305  May 29, 2025  NYK vs. IND  W   36   10
# 2      42024    1626157  0042400304  May 27, 2025    NYK @ IND  L   37    8
# 3      42024    1626157  0042400303  May 25, 2025    NYK @ IND  W   33    8
# 4      42024    1626157  0042400302  May 23, 2025  NYK vs. IND  L   28    6
# 5      42024    1626157  0042400301  May 21, 2025  NYK vs. IND  L   39   11
# 6      42024    1626157  0042400216  May 16, 2025  NYK vs. BOS  W   35    8
# 7      42024    1626157  0042400215  May 14, 2025    NYK @ BOS  L   29    5
# 8      42024    1626157  0042400214  May 12, 2025  NYK vs. BOS  W   36   11
# 9      42024    1626157  0042400213  May 10, 2025  NYK vs. BOS  L   36    5
# 10     42024    1626157  0042400212  May 07, 2025    NYK @ BOS  W   35    9
# ...

# %%
#ANT Stats
gamelog = playergamelog.PlayerGameLog(player_id='1630162', season='2024-25',season_type_all_star='Playoffs')
df_ant = gamelog.get_data_frames()[0]
df_ant["Player_Name"] = 'Anthony Edwards'
df_ant
# Out:
#    SEASON_ID  Player_ID     Game_ID     GAME_DATE      MATCHUP WL  MIN  FGM  \
# 0      42024    1630162  0042400315  May 28, 2025    MIN @ OKC  L   39    7
# 1      42024    1630162  0042400314  May 26, 2025  MIN vs. OKC  L   41    5
# 2      42024    1630162  0042400313  May 24, 2025  MIN vs. OKC  W   30   12
# 3      42024    1630162  0042400312  May 22, 2025    MIN @ OKC  L   40   12
# 4      42024    1630162  0042400311  May 20, 2025    MIN @ OKC  L   37    5
# 5      42024    1630162  0042400235  May 14, 2025  MIN vs. GSW  W   41    8
# 6      42024    1630162  0042400234  May 12, 2025    MIN @ GSW  W   33   11
# 7      42024    1630162  0042400233  May 10, 2025    MIN @ GSW  W   44   13
# 8      42024    1630162  0042400232  May 08, 2025  MIN vs. GSW  W   34    6
# 9      42024    1630162  0042400231  May 06, 2025  MIN vs. GSW  L   42    9
# 10     42024    1630162  0042400165  Apr 30, 2025    MIN @ LAL  W   43    5
# ...

# %%
final_df = pd.concat([df_mpj, df_jt, df_kat,df_ant], ignore_index=True)
final_df.to_excel("C:\\Users\\andre\\OneDrive\\Documents\\Py\\Answering Unimportant Qs With Data\\NBA Playoff Star Statistics\\nba_playoff_stats.xlsx")
# Out:
# C:\Users\andre\AppData\Local\Temp\ipykernel_14780\652525552.py:2: UserWarning: Pandas requires version '3.0.5' or newer of 'xlsxwriter' (version '3.0.3' currently installed).
#   final_df.to_excel("C:\\Users\\andre\\OneDrive\\Documents\\Py\\Answering Unimportant Qs With Data\\NBA Playoff Star Statistics\\nba_playoff_stats.xlsx")
